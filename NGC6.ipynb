# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "level-studio-403808"
client = bigquery.Client(project=project_id)

# %%
query = '''
select count (*) as count_tables from bigquery-public-data.austin_bikeshare.__TABLES__ '''

# %%
query = '''
SELECT count(*) as Count_string_coloumns from `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS` where table_name = 'bikeshare_stations' and data_type = 'string'
'''

# %%
query = '''
Select * from bigquery-public-data.austin_bikeshare.bikeshare_trips where duration_minutes > 1000 and duration_minutes is not null  '''

# %%
query = '''
SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`WHERE subscriber_type = 'Walk Up' AND end_station_name ='Stolen'  '''

# %%
df = client.query(query).to_dataframe()
df
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 1  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 2  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 3  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 4  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 5  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
# 6  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 7  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 1              2565                               Trinity & 6th Street
# 2              2565                               Trinity & 6th Street
# ...

# %%
query_job.head(3)
# Out:
#    trip_id subscriber_type bike_id bike_type                start_time  \
# 0  9209168         Local30     890   classic 2016-03-20 12:21:42+00:00
# 1  9148795         Walk Up     936   classic 2016-03-16 13:20:34+00:00
# 2  9202380         Walk Up     865   classic 2016-03-19 15:44:55+00:00
#
#    start_station_id               start_station_name end_station_id  \
# 0              2541  State Capitol @ 14th & Colorado           2538
# 1              2541  State Capitol @ 14th & Colorado           2538
# 2              2540                 17th & Guadalupe           2538
#
#                   end_station_name  duration_minutes
# 0  Bullock Museum @ Congress & MLK                25
# 1  Bullock Museum @ Congress & MLK               130
# 2  Bullock Museum @ Congress & MLK                 6
